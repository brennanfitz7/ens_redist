# %%
from my_dataset import EnsDataset

# %%
tryguy=EnsDataset(['../data/ens_083/',
 '../data/ens_050/',
 '../data/ens_007/',
 '../data/ens_108/'])

# %%
tryguy.__getitem__(0)
# Out:
# (site                                    1
#  resid                                  15
#  coord_array    [[12.988, 15.637, -4.881]]
#  x_coord                            12.988
#  y_coord                            15.637
#  z_coord                            -4.881
#  num_C                                   3
#  num_N                                   1
#  num_O                                   2
#  num_S                                   0
#  ens                               ens_083
#  Name: 0, dtype: object,
#  site                                    1
#  resid                                  15
#  coord_array    [[12.906, 14.999, -4.678]]
#  x_coord                            12.906
#  y_coord                            14.999
#  z_coord                            -4.678
#  num_C                                   3
#  num_N                                   1
#  num_O                                   2
#  num_S                                   0
# ...
