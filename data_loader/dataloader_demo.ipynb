# %%
import pandas as pd
import torch
import numpy as np
import glob


import torch_geometric
import torch_geometric.data as geom_data

from torch_geometric.data import Data

from my_dataset import EnsDataset

from format_data import load_geom_data

from my_dataloader import EnsDataLoader

# %%
ens_dirs=glob.glob('../data/*/')
ens_dirs
# Out:
# ['../data/ens_084/',
#  '../data/ens_008/',
#  '../data/ens_109/',
#  '../data/ens_060/',
#  '../data/ens_017/',
#  '../data/ens_092/',
#  '../data/ens_016/',
#  '../data/ens_117/',
#  '../data/ens_091/',
#  '../data/ens_048/',
#  '../data/ens_transglutaminase/',
#  '../data/ens_024/',
#  '../data/ens_047/',
#  '../data/ens_101/',
#  '../data/ens_056/',
#  '../data/ens_079/',
#  '../data/ens_032/',
#  '../data/ens_055/',
#  '../data/ens_064/',
#  '../data/ens_031/',
#  '../data/ens_087/',
#  '../data/ens_040/',
#  '../data/ens_063/',
#  '../data/ens_095/',
#  '../data/ens_019/',
#  '../data/ens_071/',
#  '../data/ens_028/',
#  '../data/ens_004/',
#  '../data/ens_027/',
#  '../data/ens_104/',
#  '../data/ens_059/',
#  '../data/ens_012/',
#  '../data/ens_035/',
#  '../data/ens_011/',
#  '../data/ens_112/',
#  '../data/ens_067/',
#  '../data/ens_099/',
#  '../data/ens_066/',
#  '../data/ens_120/',
#  '../data/ens_075/',
#  '../data/ens_098/',
#  '../data/ens_051/',
#  '../data/ens_074/',
#  '../data/ens_083/',
#  '../data/ens_050/',
#  '../data/ens_007/',
#  '../data/ens_108/',
#  '../data/ens_082/',
#  '../data/ens_039/',
#  '../data/ens_006/',
#  '../data/ens_107/',
#  '../data/ens_015/',
#  '../data/ens_038/',
#  '../data/ens_090/',
#  '../data/ens_014/',
#  '../data/ens_115/',
#  '../data/ens_023/',
#  '../data/ens_046/',
#  '../data/ens_100/',
#  '../data/ens_022/',
#  '../data/ens_078/',
#  '../data/ens_054/',
#  '../data/ens_077/',
#  '../data/ens_030/',
#  '../data/ens_086/',
#  '../data/ens_062/',
#  '../data/ens_lac/',
#  '../data/ens_085/',
#  '../data/ens_s100A4/',
#  '../data/ens_094/',
#  '../data/ens_061/',
#  '../data/ens_018/',
#  '../data/ens_119/',
#  '../data/ens_070/',
#  '../data/ens_093/',
#  '../data/ens_118/',
#  '../data/ens_026/',
#  '../data/ens_049/',
#  '../data/ens_002/',
#  '../data/ens_103/',
#  '../data/ens_058/',
#  '../data/ens_025/',
#  '../data/ens_034/',
#  '../data/ens_001/',
#  '../data/ens_102/',
#  '../data/ens_111/',
#  '../data/ens_033/',
#  '../data/ens_089/',
#  '../data/ens_042/',
#  '../data/ens_110/',
#  '../data/ens_065/',
#  '../data/ens_088/',
#  '../data/ens_041/',
#  '../data/ens_097/',
#  '../data/ens_073/',
#  '../data/ens_096/',
#  '../data/ens_029/',
#  '../data/ens_081/',
#  '../data/ens_005/',
#  '../data/ens_106/',
#  '../data/ens_080/',
#  '../data/ens_037/',
#  '../data/ens_105/',
#  '../data/ens_114/',
#  '../data/ens_036/',
#  '../data/ens_113/',
#  '../data/ens_068/',
#  '../data/ens_021/',
#  '../data/ens_044/',
#  '../data/ens_053/',
#  '../data/ens_020/',
#  '../data/ens_076/',
#  '../data/ens_ERRG/',
#  '../data/ens_052/']

# %%
len(ens_dirs)
# Out:
# 114

# %%
train_split=ens_dirs[0:80]
val_split=ens_dirs[80:97]
test_split=ens_dirs[97:115]

# %%
train_dataset=EnsDataset(train_split)
val_dataset=EnsDataset(val_split)
test_dataset=EnsDataset(test_split)

# %%
train_dataset.__getitem__(0)
# Out:
# (site                                    1
#  resid                                  14
#  coord_array    [[8.048, -10.233, 26.344]]
#  x_coord                             8.048
#  y_coord                           -10.233
#  z_coord                            26.344
#  num_C                                   6
#  num_N                                   4
#  num_O                                   1
#  num_S                                   0
#  ens                               ens_084
#  Name: 0, dtype: object,
#  site                                    1
#  resid                                  14
#  coord_array    [[8.638, -10.547, 26.755]]
#  x_coord                             8.638
#  y_coord                           -10.547
#  z_coord                            26.755
#  num_C                                   6
#  num_N                                   4
#  num_O                                   1
#  num_S                                   0
#  ens                               ens_084
#  Name: 0, dtype: object,
#  0.1030694246292114)

# %% [markdown]
# Due to how long it will take to load in any of the data splits, I'd recommend loading in this minisplit

# %%
minisplit=ens_dirs[0:5]
mini_dataset=EnsDataset(minisplit)

# %%
EnsDataLoader(minisplit,batch_size=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 EnsDataLoader(minisplit,batch_size=1)
#
# File /gpfs/home/bfitzger/ens_redist/data_loader/my_dataloader.py:26, in EnsDataLoader.__init__(self, ens_dirs, batch_size, shuffle, num_workers, training)
#      22 self.labels=ddg_df.max_diff_ddg
#      24 self.dataset = load_geom_data(self.struct1)
# ---> 26 super().__init__(self.dataset1, batch_size, shuffle, num_workers)
#
# AttributeError: 'EnsDataLoader' object has no attribute 'dataset1'
